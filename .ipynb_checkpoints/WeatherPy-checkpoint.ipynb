# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key

from api_keys import weather_api_key

# Incorporated citipy to determine city using latitude and longitude

from citipy import citipy

# CSV File

output_data_file = "output_data/cities.csv"

# Latitude/Longitude range

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Empty lists for holding lat/lng coordinates and cities

lat_lngs = []
cities = []

# Random lat/lng combinations

lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 629

# %%
# Base URL for Weather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2e7be3fbf6a6ca5ee22f83c7998246c"

# Empty ist for holding the city data

city_data = []

# Print to logger

print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters

record_count = 1
set_count = 1

# Loop through all the cities in the list

for i, city in enumerate(cities):
        
    # Group cities in order to log them
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create unique URL for each city
    
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    
    record_count += 1

    # Run an API request for each of the cities
    
    try:
        
        # Retrieve data from JSON
        
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dingzhou
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | manado
# Processing Record 5 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | kaspiysk
# Processing Record 7 of Set 1 | schermbeck
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | joshimath
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | ostrovnoy
# Processing Record 13 of Set 1 | saint-philippe
# Processing Record 14 of Set 1 | wokha
# Processing Record 15 of Set 1 | manono
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | chuy
# Processing Record 18 of Set 1 | arona
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | saint-augustin
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | snezhnogorsk
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | yulara
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | malartic
# Processing Record 32 of Set 1 | bathsheba
# Processing Record 33 of Set 1 | tahoua
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | lubango
# Processing Record 36 of Set 1 | cherskiy
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | jumla
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | paris
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | barra
# Processing Record 44 of Set 1 | seoul
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | george town
# Processing Record 47 of Set 1 | itoman
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | fortuna
# Processing Record 0 of Set 2 | prestea
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | guerrero negro
# Processing Record 3 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 2 | kamenka
# Processing Record 5 of Set 2 | dauphin
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | puerto quijarro
# Processing Record 8 of Set 2 | nagothana
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | carnarvon
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | katobu
# Processing Record 15 of Set 2 | sekoma
# Processing Record 16 of Set 2 | catamarca
# Processing Record 17 of Set 2 | waterford
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | talnakh
# Processing Record 21 of Set 2 | camacupa
# Processing Record 22 of Set 2 | san clemente
# Processing Record 23 of Set 2 | riyadh
# Processing Record 24 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 25 of Set 2 | margate
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 2 | oranjemund
# Processing Record 29 of Set 2 | las delicias
# Processing Record 30 of Set 2 | castro
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | colchester
# Processing Record 33 of Set 2 | tabukiniberu
# City not found. Skipping...
# Processing Record 34 of Set 2 | ocho rios
# Processing Record 35 of Set 2 | saint-francois
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | te anau
# Processing Record 38 of Set 2 | cootamundra
# Processing Record 39 of Set 2 | port lincoln
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | ponta do sol
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | muroto
# Processing Record 44 of Set 2 | tolaga bay
# Processing Record 45 of Set 2 | ngorongoro
# Processing Record 46 of Set 2 | lucban
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 2 | ucluelet
# Processing Record 0 of Set 3 | teknaf
# Processing Record 1 of Set 3 | upata
# Processing Record 2 of Set 3 | kupang
# Processing Record 3 of Set 3 | kampong thum
# Processing Record 4 of Set 3 | buala
# Processing Record 5 of Set 3 | kologriv
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | san rafael
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | samarai
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | richards bay
# Processing Record 13 of Set 3 | rio grande
# Processing Record 14 of Set 3 | iqaluit
# Processing Record 15 of Set 3 | half moon bay
# Processing Record 16 of Set 3 | jomalig
# City not found. Skipping...
# Processing Record 17 of Set 3 | dimapur
# Processing Record 18 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 3 | kaitangata
# Processing Record 20 of Set 3 | aripuana
# Processing Record 21 of Set 3 | balykshi
# Processing Record 22 of Set 3 | oussouye
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 3 | houston
# Processing Record 26 of Set 3 | butaritari
# Processing Record 27 of Set 3 | sidi ali
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | new norfolk
# Processing Record 30 of Set 3 | haines junction
# Processing Record 31 of Set 3 | odienne
# Processing Record 32 of Set 3 | ponta delgada
# Processing Record 33 of Set 3 | gushikawa
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | takoradi
# Processing Record 36 of Set 3 | ndjole
# Processing Record 37 of Set 3 | avera
# Processing Record 38 of Set 3 | sri aman
# Processing Record 39 of Set 3 | powell river
# Processing Record 40 of Set 3 | cayenne
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | cabo san lucas
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | miyako
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | lishui
# Processing Record 47 of Set 3 | chardara
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | karratha
# Processing Record 0 of Set 4 | cidreira
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | lorengau
# Processing Record 3 of Set 4 | yeniseysk
# Processing Record 4 of Set 4 | jacareacanga
# Processing Record 5 of Set 4 | saint-pierre
# Processing Record 6 of Set 4 | provideniya
# Processing Record 7 of Set 4 | longyearbyen
# Processing Record 8 of Set 4 | west bay
# Processing Record 9 of Set 4 | thompson
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | huarmey
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | marsh harbour
# Processing Record 14 of Set 4 | namatanai
# Processing Record 15 of Set 4 | the pas
# Processing Record 16 of Set 4 | tatarsk
# Processing Record 17 of Set 4 | roma
# Processing Record 18 of Set 4 | vargashi
# Processing Record 19 of Set 4 | ornskoldsvik
# Processing Record 20 of Set 4 | beloha
# Processing Record 21 of Set 4 | panalingaan
# Processing Record 22 of Set 4 | khuzhir
# Processing Record 23 of Set 4 | hato mayor
# Processing Record 24 of Set 4 | plouzane
# Processing Record 25 of Set 4 | grindavik
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | saskylakh
# Processing Record 28 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 4 | izhma
# Processing Record 30 of Set 4 | hualmay
# Processing Record 31 of Set 4 | upernavik
# Processing Record 32 of Set 4 | tiarei
# Processing Record 33 of Set 4 | pisco
# Processing Record 34 of Set 4 | makung
# City not found. Skipping...
# Processing Record 35 of Set 4 | graaff-reinet
# Processing Record 36 of Set 4 | kalaleh
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | san jose
# Processing Record 39 of Set 4 | manicore
# Processing Record 40 of Set 4 | vegreville
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | newala
# Processing Record 43 of Set 4 | port-gentil
# Processing Record 44 of Set 4 | husavik
# Processing Record 45 of Set 4 | coria
# Processing Record 46 of Set 4 | touros
# Processing Record 47 of Set 4 | victoria
# Processing Record 48 of Set 4 | curaca
# Processing Record 49 of Set 4 | umm lajj
# Processing Record 0 of Set 5 | coronado
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | padang
# Processing Record 3 of Set 5 | flinders
# Processing Record 4 of Set 5 | baruun-urt
# Processing Record 5 of Set 5 | harnosand
# Processing Record 6 of Set 5 | mayor pablo lagerenza
# Processing Record 7 of Set 5 | namtsy
# Processing Record 8 of Set 5 | viedma
# Processing Record 9 of Set 5 | lazaro cardenas
# Processing Record 10 of Set 5 | brae
# Processing Record 11 of Set 5 | boguchany
# Processing Record 12 of Set 5 | naze
# Processing Record 13 of Set 5 | grand gaube
# Processing Record 14 of Set 5 | kavieng
# Processing Record 15 of Set 5 | sao filipe
# Processing Record 16 of Set 5 | kodiak
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | malayal
# Processing Record 19 of Set 5 | gwadar
# Processing Record 20 of Set 5 | le vauclin
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | innisfail
# Processing Record 23 of Set 5 | luderitz
# Processing Record 24 of Set 5 | manzhouli
# Processing Record 25 of Set 5 | kavaratti
# Processing Record 26 of Set 5 | hirara
# Processing Record 27 of Set 5 | kathu
# Processing Record 28 of Set 5 | obo
# Processing Record 29 of Set 5 | alyangula
# Processing Record 30 of Set 5 | idanre
# Processing Record 31 of Set 5 | mount gambier
# Processing Record 32 of Set 5 | trairi
# Processing Record 33 of Set 5 | aloleng
# Processing Record 34 of Set 5 | bonavista
# Processing Record 35 of Set 5 | evanston
# Processing Record 36 of Set 5 | inuvik
# Processing Record 37 of Set 5 | aswan
# Processing Record 38 of Set 5 | urusha
# Processing Record 39 of Set 5 | arraial do cabo
# Processing Record 40 of Set 5 | djambala
# Processing Record 41 of Set 5 | puerto ayacucho
# Processing Record 42 of Set 5 | ouro fino
# Processing Record 43 of Set 5 | mhango
# Processing Record 44 of Set 5 | morehead
# Processing Record 45 of Set 5 | athabasca
# Processing Record 46 of Set 5 | kungurtug
# Processing Record 47 of Set 5 | pascagoula
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | khorixas
# Processing Record 0 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | pemagatsel
# Processing Record 3 of Set 6 | nemuro
# Processing Record 4 of Set 6 | virginia beach
# Processing Record 5 of Set 6 | rio gallegos
# Processing Record 6 of Set 6 | saint anthony
# Processing Record 7 of Set 6 | ust-ishim
# Processing Record 8 of Set 6 | peru
# Processing Record 9 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 6 | iracoubo
# Processing Record 11 of Set 6 | kutum
# Processing Record 12 of Set 6 | charleston
# Processing Record 13 of Set 6 | high level
# Processing Record 14 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 6 | kloulklubed
# Processing Record 16 of Set 6 | flin flon
# Processing Record 17 of Set 6 | tuatapere
# Processing Record 18 of Set 6 | fort morgan
# Processing Record 19 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 6 | saldanha
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | kembe
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | mount pleasant
# Processing Record 25 of Set 6 | manokwari
# Processing Record 26 of Set 6 | bubaque
# Processing Record 27 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 28 of Set 6 | aksarka
# Processing Record 29 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 6 | krasnorechenskiy
# Processing Record 31 of Set 6 | hofn
# Processing Record 32 of Set 6 | ippy
# Processing Record 33 of Set 6 | varhaug
# Processing Record 34 of Set 6 | nebolchi
# Processing Record 35 of Set 6 | gamba
# Processing Record 36 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | baghdad
# Processing Record 38 of Set 6 | kieta
# Processing Record 39 of Set 6 | tiguha
# Processing Record 40 of Set 6 | paamiut
# Processing Record 41 of Set 6 | bilma
# Processing Record 42 of Set 6 | kununurra
# Processing Record 43 of Set 6 | ternate
# Processing Record 44 of Set 6 | quebo
# Processing Record 45 of Set 6 | oyama
# Processing Record 46 of Set 6 | key west
# Processing Record 47 of Set 6 | komsomolskiy
# Processing Record 48 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 6 | loksa
# Processing Record 0 of Set 7 | antofagasta
# Processing Record 1 of Set 7 | san andres
# Processing Record 2 of Set 7 | los llanos de aridane
# Processing Record 3 of Set 7 | nouadhibou
# Processing Record 4 of Set 7 | maues
# Processing Record 5 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 7 | geraldton
# Processing Record 7 of Set 7 | jalu
# Processing Record 8 of Set 7 | kruisfontein
# Processing Record 9 of Set 7 | hobyo
# Processing Record 10 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 7 | faya
# Processing Record 12 of Set 7 | suda
# Processing Record 13 of Set 7 | kropotkin
# Processing Record 14 of Set 7 | svetlyy
# Processing Record 15 of Set 7 | dubai
# Processing Record 16 of Set 7 | whitehorse
# Processing Record 17 of Set 7 | faanui
# Processing Record 18 of Set 7 | ambilobe
# Processing Record 19 of Set 7 | hambantota
# Processing Record 20 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 7 | souillac
# Processing Record 22 of Set 7 | bekhtery
# Processing Record 23 of Set 7 | weligama
# Processing Record 24 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | vallenar
# Processing Record 26 of Set 7 | safaga
# Processing Record 27 of Set 7 | bulungu
# Processing Record 28 of Set 7 | kangaatsiaq
# Processing Record 29 of Set 7 | alice town
# Processing Record 30 of Set 7 | mildura
# Processing Record 31 of Set 7 | mayahi
# Processing Record 32 of Set 7 | alice springs
# Processing Record 33 of Set 7 | alofi
# Processing Record 34 of Set 7 | palana
# Processing Record 35 of Set 7 | tabora
# Processing Record 36 of Set 7 | madoc
# Processing Record 37 of Set 7 | aurillac
# Processing Record 38 of Set 7 | ialibu
# Processing Record 39 of Set 7 | chiang rai
# Processing Record 40 of Set 7 | lata
# Processing Record 41 of Set 7 | sao gabriel da cachoeira
# Processing Record 42 of Set 7 | severo-kurilsk
# Processing Record 43 of Set 7 | altamirano
# Processing Record 44 of Set 7 | manoel urbano
# Processing Record 45 of Set 7 | kahului
# Processing Record 46 of Set 7 | butembo
# Processing Record 47 of Set 7 | sungairaya
# Processing Record 48 of Set 7 | almeirim
# Processing Record 49 of Set 7 | itarema
# Processing Record 0 of Set 8 | narsaq
# Processing Record 1 of Set 8 | roebourne
# Processing Record 2 of Set 8 | nioro
# Processing Record 3 of Set 8 | charters towers
# Processing Record 4 of Set 8 | tiksi
# Processing Record 5 of Set 8 | dongsheng
# Processing Record 6 of Set 8 | idrinskoye
# Processing Record 7 of Set 8 | katsuura
# Processing Record 8 of Set 8 | salalah
# Processing Record 9 of Set 8 | bonthe
# Processing Record 10 of Set 8 | douentza
# Processing Record 11 of Set 8 | callaguip
# Processing Record 12 of Set 8 | coahuayana
# Processing Record 13 of Set 8 | la ciotat
# Processing Record 14 of Set 8 | baoding
# Processing Record 15 of Set 8 | pincher creek
# Processing Record 16 of Set 8 | quatre cocos
# Processing Record 17 of Set 8 | la asuncion
# Processing Record 18 of Set 8 | beringovskiy
# Processing Record 19 of Set 8 | wilmington
# Processing Record 20 of Set 8 | mercedes
# Processing Record 21 of Set 8 | baclesu
# City not found. Skipping...
# Processing Record 22 of Set 8 | dali
# Processing Record 23 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 24 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 25 of Set 8 | oktyabrskiy
# Processing Record 26 of Set 8 | fare
# Processing Record 27 of Set 8 | aykhal
# Processing Record 28 of Set 8 | ancud
# Processing Record 29 of Set 8 | lasa
# Processing Record 30 of Set 8 | fallon
# Processing Record 31 of Set 8 | kjollefjord
# Processing Record 32 of Set 8 | fukue
# Processing Record 33 of Set 8 | jaguaruna
# Processing Record 34 of Set 8 | maragogi
# Processing Record 35 of Set 8 | biak
# Processing Record 36 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 8 | deputatskiy
# Processing Record 38 of Set 8 | barda
# Processing Record 39 of Set 8 | dorgos
# Processing Record 40 of Set 8 | abha
# Processing Record 41 of Set 8 | yatou
# Processing Record 42 of Set 8 | khasan
# Processing Record 43 of Set 8 | axim
# Processing Record 44 of Set 8 | mezen
# Processing Record 45 of Set 8 | coquimbo
# Processing Record 46 of Set 8 | zhigansk
# Processing Record 47 of Set 8 | wanning
# Processing Record 48 of Set 8 | thilogne
# City not found. Skipping...
# Processing Record 49 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 0 of Set 9 | boca do acre
# Processing Record 1 of Set 9 | berestechko
# Processing Record 2 of Set 9 | clyde river
# Processing Record 3 of Set 9 | airai
# Processing Record 4 of Set 9 | roald
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | chernyshevskiy
# Processing Record 7 of Set 9 | holly hill
# Processing Record 8 of Set 9 | mayo
# Processing Record 9 of Set 9 | pakhtakoron
# Processing Record 10 of Set 9 | laguna
# Processing Record 11 of Set 9 | bend
# Processing Record 12 of Set 9 | tabas
# Processing Record 13 of Set 9 | wladyslawowo
# Processing Record 14 of Set 9 | pallasovka
# Processing Record 15 of Set 9 | achacachi
# Processing Record 16 of Set 9 | sibu
# Processing Record 17 of Set 9 | guangyuan
# Processing Record 18 of Set 9 | san quintin
# Processing Record 19 of Set 9 | kaeo
# Processing Record 20 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 9 | ascension
# Processing Record 22 of Set 9 | northam
# Processing Record 23 of Set 9 | bima
# Processing Record 24 of Set 9 | waiuku
# Processing Record 25 of Set 9 | chenzhou
# Processing Record 26 of Set 9 | inawashiro
# Processing Record 27 of Set 9 | rebrikha
# Processing Record 28 of Set 9 | olafsvik
# Processing Record 29 of Set 9 | tamworth
# Processing Record 30 of Set 9 | vao
# Processing Record 31 of Set 9 | kenai
# Processing Record 32 of Set 9 | bilibino
# Processing Record 33 of Set 9 | tautira
# Processing Record 34 of Set 9 | banda aceh
# Processing Record 35 of Set 9 | pacific grove
# Processing Record 36 of Set 9 | tingo maria
# Processing Record 37 of Set 9 | lagoa
# Processing Record 38 of Set 9 | magadan
# Processing Record 39 of Set 9 | uray
# Processing Record 40 of Set 9 | andenes
# Processing Record 41 of Set 9 | porto novo
# Processing Record 42 of Set 9 | chapais
# Processing Record 43 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 9 | belyy yar
# Processing Record 45 of Set 9 | barsovo
# Processing Record 46 of Set 9 | poya
# Processing Record 47 of Set 9 | mount isa
# Processing Record 48 of Set 9 | bambanglipuro
# Processing Record 49 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 0 of Set 10 | oliveira dos brejinhos
# Processing Record 1 of Set 10 | bunia
# Processing Record 2 of Set 10 | goshogawara
# Processing Record 3 of Set 10 | mareeba
# Processing Record 4 of Set 10 | punakha
# Processing Record 5 of Set 10 | mahajanga
# Processing Record 6 of Set 10 | orlik
# Processing Record 7 of Set 10 | svetlaya
# Processing Record 8 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 10 | korba
# Processing Record 10 of Set 10 | linao
# Processing Record 11 of Set 10 | klyuchi
# Processing Record 12 of Set 10 | betare oya
# Processing Record 13 of Set 10 | goure
# Processing Record 14 of Set 10 | erzin
# Processing Record 15 of Set 10 | coffs harbour
# Processing Record 16 of Set 10 | fort collins
# Processing Record 17 of Set 10 | dingle
# Processing Record 18 of Set 10 | neka
# Processing Record 19 of Set 10 | nyurba
# Processing Record 20 of Set 10 | atambua
# Processing Record 21 of Set 10 | korla
# Processing Record 22 of Set 10 | hovd
# Processing Record 23 of Set 10 | uruzgan
# Processing Record 24 of Set 10 | taoudenni
# Processing Record 25 of Set 10 | liverpool
# Processing Record 26 of Set 10 | el oro
# Processing Record 27 of Set 10 | marshall
# Processing Record 28 of Set 10 | lokosovo
# Processing Record 29 of Set 10 | areka
# Processing Record 30 of Set 10 | gambela
# Processing Record 31 of Set 10 | shunyi
# Processing Record 32 of Set 10 | nelson bay
# Processing Record 33 of Set 10 | pelym
# Processing Record 34 of Set 10 | tanshui
# City not found. Skipping...
# Processing Record 35 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 36 of Set 10 | kalmunai
# Processing Record 37 of Set 10 | namibe
# Processing Record 38 of Set 10 | shyryayeve
# Processing Record 39 of Set 10 | stamsund
# City not found. Skipping...
# Processing Record 40 of Set 10 | luganville
# Processing Record 41 of Set 10 | sekudai
# Processing Record 42 of Set 10 | solnechnyy
# Processing Record 43 of Set 10 | constitucion
# Processing Record 44 of Set 10 | launceston
# Processing Record 45 of Set 10 | tiruchchendur
# Processing Record 46 of Set 10 | yemelyanovo
# Processing Record 47 of Set 10 | wawa
# Processing Record 48 of Set 10 | duz
# City not found. Skipping...
# Processing Record 49 of Set 10 | galatini
# Processing Record 0 of Set 11 | kapoeta
# Processing Record 1 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 11 | sawtell
# Processing Record 4 of Set 11 | aklavik
# Processing Record 5 of Set 11 | cobh
# Processing Record 6 of Set 11 | kuching
# Processing Record 7 of Set 11 | manadhoo
# Processing Record 8 of Set 11 | bitung
# Processing Record 9 of Set 11 | cockburn town
# Processing Record 10 of Set 11 | lethem
# Processing Record 11 of Set 11 | verkhnevilyuysk
# Processing Record 12 of Set 11 | opuwo
# Processing Record 13 of Set 11 | maarianhamina
# Processing Record 14 of Set 11 | nanortalik
# Processing Record 15 of Set 11 | tateyama
# Processing Record 16 of Set 11 | general roca
# Processing Record 17 of Set 11 | tamboril
# Processing Record 18 of Set 11 | zhezkazgan
# Processing Record 19 of Set 11 | antalaha
# Processing Record 20 of Set 11 | kulhudhuffushi
# Processing Record 21 of Set 11 | senador jose porfirio
# Processing Record 22 of Set 11 | barranca
# Processing Record 23 of Set 11 | koumac
# Processing Record 24 of Set 11 | thinadhoo
# Processing Record 25 of Set 11 | sangar
# Processing Record 26 of Set 11 | robertsport
# Processing Record 27 of Set 11 | kilindoni
# Processing Record 28 of Set 11 | sirkali
# City not found. Skipping...
# Processing Record 29 of Set 11 | shimoda
# Processing Record 30 of Set 11 | morden
# Processing Record 31 of Set 11 | pandan
# Processing Record 32 of Set 11 | natal
# Processing Record 33 of Set 11 | waipawa
# Processing Record 34 of Set 11 | boyolangu
# Processing Record 35 of Set 11 | valdivia
# Processing Record 36 of Set 11 | nadapuram
# Processing Record 37 of Set 11 | valley
# Processing Record 38 of Set 11 | coos bay
# Processing Record 39 of Set 11 | marienburg
# Processing Record 40 of Set 11 | chervona sloboda
# Processing Record 41 of Set 11 | vila
# Processing Record 42 of Set 11 | port hardy
# Processing Record 43 of Set 11 | juegang
# Processing Record 44 of Set 11 | ust-kuyga
# Processing Record 45 of Set 11 | makakilo city
# Processing Record 46 of Set 11 | bereda
# Processing Record 47 of Set 11 | djibo
# Processing Record 48 of Set 11 | lages
# Processing Record 49 of Set 11 | lesnoye
# Processing Record 0 of Set 12 | bandarbeyla
# Processing Record 1 of Set 12 | pahalgam
# Processing Record 2 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 12 | berlevag
# Processing Record 4 of Set 12 | miguel calmon
# Processing Record 5 of Set 12 | calama
# Processing Record 6 of Set 12 | lavrentiya
# Processing Record 7 of Set 12 | poli
# Processing Record 8 of Set 12 | camopi
# Processing Record 9 of Set 12 | crepaja
# Processing Record 10 of Set 12 | santa rosalia
# Processing Record 11 of Set 12 | suntar
# Processing Record 12 of Set 12 | coruripe
# Processing Record 13 of Set 12 | owosso
# Processing Record 14 of Set 12 | conroe
# Processing Record 15 of Set 12 | santa cruz
# Processing Record 16 of Set 12 | ecroignard
# Processing Record 17 of Set 12 | pueblo
# Processing Record 18 of Set 12 | carbondale
# Processing Record 19 of Set 12 | ahuimanu
# Processing Record 20 of Set 12 | dickinson
# Processing Record 21 of Set 12 | igra
# Processing Record 22 of Set 12 | bure
# Processing Record 23 of Set 12 | bowen
# Processing Record 24 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 25 of Set 12 | blackwater
# Processing Record 26 of Set 12 | ankang
# Processing Record 27 of Set 12 | altamira
# Processing Record 28 of Set 12 | turukhansk
# Processing Record 29 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 12 | donghai
# Processing Record 31 of Set 12 | manzanillo
# Processing Record 32 of Set 12 | breves
# Processing Record 33 of Set 12 | rio pardo
# Processing Record 34 of Set 12 | marovoay
# Processing Record 35 of Set 12 | ostersund
# Processing Record 36 of Set 12 | baculin
# Processing Record 37 of Set 12 | vostok
# Processing Record 38 of Set 12 | dakar
# Processing Record 39 of Set 12 | vila franca do campo
# Processing Record 40 of Set 12 | sao joao da barra
# Processing Record 41 of Set 12 | paita
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 # Convert array of JSONs into Pandas DataFrame
    
city_data_df = pd.DataFrame(city_data)

# Show Record Count

city_data_df.count()
# Out:
# City          541
# Lat           541
# Lng           541
# Max Temp      541
# Humidity      541
# Cloudiness    541
# Wind Speed    541
# Country       541
# Date          541
# dtype: int64

# %%
 # Display the City Data Frame
    
city_data_pd.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     dingzhou  38.5131  114.9956     48.31        65         100        5.82
# 1      rikitea -23.1203 -134.9692     75.45        72          69       18.92
# 2  yellowknife  62.4560 -114.3525     42.42        94          90        1.99
# 3       manado   1.4870  124.8455     83.17        83          20        1.14
# 4     kaspiysk  42.8816   47.6392     44.78        81          90       11.01
#
#   Country        Date
# 0      CN  1635205439
# 1      PF  1635205439
# 2      CA  1635205439
# 3      ID  1635205440
# 4      RU  1635205440

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  541.000000  541.000000  541.000000  541.000000  541.000000  541.000000
# mean    19.018219   19.440757   60.342717   74.645102   58.275416    7.469242
# std     32.747177   91.380311   20.459238   18.632601   37.622195    5.681098
# min    -54.800000 -175.200000  -22.650000   10.000000    0.000000    0.000000
# 25%     -7.950000  -61.300300   47.230000   65.000000   20.000000    3.090000
# 50%     21.444700   21.886500   64.540000   78.000000   70.000000    6.150000
# 75%     46.538900  104.888700   77.310000   89.000000   95.000000    9.950000
# max     78.218600  179.316700   91.170000  100.000000  100.000000   35.480000
#
#                Date
# count  5.410000e+02
# mean   1.635206e+09
# std    1.230501e+02
# min    1.635205e+09
# 25%    1.635205e+09
# 50%    1.635206e+09
# 75%    1.635206e+09
# max    1.635206e+09

# %%
 #  Get the indices of cities that have humidity over 100%
    .
dirty_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
dirty_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
 # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

clean_city_data = city_data_pd.drop(dirty_city_data, inplace=False)
clean_city_data.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     dingzhou  38.5131  114.9956     48.31        65         100        5.82
# 1      rikitea -23.1203 -134.9692     75.45        72          69       18.92
# 2  yellowknife  62.4560 -114.3525     42.42        94          90        1.99
# 3       manado   1.4870  124.8455     83.17        83          20        1.14
# 4     kaspiysk  42.8816   47.6392     44.78        81          90       11.01
#
#   Country        Date
# 0      CN  1635205439
# 1      PF  1635205439
# 2      CA  1635205439
# 3      ID  1635205440
# 4      RU  1635205440

# %%
# Extract relevant fields from the data frame

lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv

clean_city_data.to_csv(output_data_file, index_label="City_ID")
